# %% [markdown]
# # Representación de información jerárquica mediante gráfico *Sunburst*

# %%
# !pip install plotly==4.8 
import pandas as pd
import plotly.express as px
# Out:
# Collecting plotly==4.8
#   Downloading plotly-4.8.0-py2.py3-none-any.whl (11.5 MB)
#      |████████████████████████████████| 11.5 MB 4.7 MB/s
# Requirement already satisfied: retrying>=1.3.3 in /usr/local/lib/python3.7/dist-packages (from plotly==4.8) (1.3.3)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from plotly==4.8) (1.15.0)
# Installing collected packages: plotly
#   Attempting uninstall: plotly
#     Found existing installation: plotly 4.4.1
#     Uninstalling plotly-4.4.1:
#       Successfully uninstalled plotly-4.4.1
# Successfully installed plotly-4.8.0

# %% [markdown]
# Cargamos datos sobre posiciones financieras (ficticias) en distintos activos de diversas categorías financieras.

# %%
df_agg = pd.read_csv('agg_data_dataviz.csv',sep=';')
df_agg.head()
# Out:
#     CATEGORY_L1       CATEGORY_L2   CATEGORY_L3            CATEGORY_L4    VALOR
# 0  ALTERNATIVOS  RETORNO ABSOLUTO   PERFIL ALTO  EQUITY MARKET NEUTRAL  1000000
# 1  ALTERNATIVOS  RETORNO ABSOLUTO   PERFIL ALTO       MULTI ESTRATEGIA    50000
# 2  ALTERNATIVOS  RETORNO ABSOLUTO   PERFIL ALTO            VOLATILIDAD   100000
# 3  ALTERNATIVOS  RETORNO ABSOLUTO  PERFIL MEDIO                DIVISAS   200000
# 4  ALTERNATIVOS  RETORNO ABSOLUTO  PERFIL MEDIO       MULTI ESTRATEGIA   100000

# %%
df_agg['CATEGORY_L2'].unique()
# Out:
# array(['RETORNO ABSOLUTO', 'CREDITO', 'GOBIERNOS', 'HIGH YIELD',
#        'EMERGENTE', 'EUROPA', 'GLOBAL', 'SECTORES', 'TEMATICOS'],
#       dtype=object)

# %% [markdown]
# Representamos mediante un gráfico dinámico de tipo *sunburst*.

# %%
fig = px.sunburst(df_agg, path=['CATEGORY_L1','CATEGORY_L2','CATEGORY_L3','CATEGORY_L4'], values='VALOR')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="274653e7-3406-4fa2-8500-29a17eb24614" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("274653e7-3406-4fa2-8500-29a17eb24614")) {
#                     Plotly.newPlot(
#                         '274653e7-3406-4fa2-8500-29a17eb24614',
#                         [{"branchvalues": "total", "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "labels=%{label}<br>VALOR=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>", "ids": ["RENTA VARIABLE/TEMATICOS/CUIDADO DEL MEDIO AMBIENTE/AGUA", "RENTA VARIABLE/EUROPA/MONOPAIS/ALEMANIA", "RENTA VARIABLE/GLOBAL/MONOPAIS/AUSTRALIA", "RENTA VARIABLE/EMERGENTE/MONOPAIS/BRASIL", "RENTA VARIABLE/EMERGENTE/MONOPAIS/CHINA", "RENTA FIJA/CREDITO/EUROPA/CORTO", "RENTA FIJA/HIGH YIELD/EUROPA/CORTO", "RENTA FIJA/CREDITO/USA/CORTO", "RENTA FIJA/HIGH YIELD/USA/CORTO", "ALTERNATIVOS/RETORNO ABSOLUTO/PERFIL MEDIO/DIVISAS", "RENTA VARIABLE/TEMATICOS/INVERSION SOCIALMENTE RESPONSABLE/EEUU", "RENTA VARIABLE/TEMATICOS/INVERSION SOCIALMENTE RESPONSABLE/EMERGENTES", "ALTERNATIVOS/RETORNO ABSOLUTO/PERFIL ALTO/EQUITY MARKET NEUTRAL", "RENTA VARIABLE/TEMATICOS/INVERSION SOCIALMENTE RESPONSABLE/EUROPA", "RENTA VARIABLE/SECTORES/TECNOLOGIA/EUROPA", "RENTA VARIABLE/SECTORES/CONSUMO ESTABLE/GLOBAL", "RENTA VARIABLE/SECTORES/ENERGIA/GLOBAL", "RENTA VARIABLE/TEMATICOS/INVERSION SOCIALMENTE RESPONSABLE/GLOBAL", "RENTA VARIABLE/SECTORES/TECNOLOGIA/GLOBAL", "RENTA VARIABLE/EUROPA/PANEUROPEO/GROWTH", "RENTA VARIABLE/GLOBAL/MONOPAIS/HONG KONG", "RENTA FIJA/CREDITO/EUROPA/LARGO", "RENTA FIJA/GOBIERNOS/EUROPA/LARGO", "RENTA FIJA/HIGH YIELD/EUROPA/LARGO", "RENTA FIJA/CREDITO/USA/LARGO", "RENTA FIJA/GOBIERNOS/USA/LARGO", "RENTA FIJA/HIGH YIELD/USA/LARGO", "RENTA VARIABLE/TEMATICOS/CUIDADO DEL MEDIO AMBIENTE/MADERA", "ALTERNATIVOS/RETORNO ABSOLUTO/PERFIL ALTO/MULTI ESTRATEGIA", "ALTERNATIVOS/RETORNO ABSOLUTO/PERFIL MEDIO/MULTI ESTRATEGIA", "RENTA VARIABLE/EUROPA/PANEUROPEO/SMALL CAP", "RENTA VARIABLE/EUROPA/MONOPAIS/SUIZA", "RENTA VARIABLE/EMERGENTE/MONOPAIS/TURQUIA", "RENTA VARIABLE/EUROPA/MONOPAIS/UK", "RENTA VARIABLE/EUROPA/PANEUROPEO/VALUE", "ALTERNATIVOS/RETORNO ABSOLUTO/PERFIL ALTO/VOLATILIDAD", "RENTA VARIABLE/SECTORES/CONSUMO ESTABLE", "RENTA VARIABLE/TEMATICOS/CUIDADO DEL MEDIO AMBIENTE", "RENTA VARIABLE/SECTORES/ENERGIA", "RENTA FIJA/CREDITO/EUROPA", "RENTA FIJA/GOBIERNOS/EUROPA", "RENTA FIJA/HIGH YIELD/EUROPA", "RENTA VARIABLE/TEMATICOS/INVERSION SOCIALMENTE RESPONSABLE", "RENTA VARIABLE/EMERGENTE/MONOPAIS", "RENTA VARIABLE/EUROPA/MONOPAIS", "RENTA VARIABLE/GLOBAL/MONOPAIS", "RENTA VARIABLE/EUROPA/PANEUROPEO", "ALTERNATIVOS/RETORNO ABSOLUTO/PERFIL ALTO", "ALTERNATIVOS/RETORNO ABSOLUTO/PERFIL MEDIO", "RENTA VARIABLE/SECTORES/TECNOLOGIA", "RENTA FIJA/CREDITO/USA", "RENTA FIJA/GOBIERNOS/USA", "RENTA FIJA/HIGH YIELD/USA", "RENTA FIJA/CREDITO", "RENTA VARIABLE/EMERGENTE", "RENTA VARIABLE/EUROPA", "RENTA VARIABLE/GLOBAL", "RENTA FIJA/GOBIERNOS", "RENTA FIJA/HIGH YIELD", "ALTERNATIVOS/RETORNO ABSOLUTO", "RENTA VARIABLE/SECTORES", "RENTA VARIABLE/TEMATICOS", "ALTERNATIVOS", "RENTA FIJA", "RENTA VARIABLE"], "labels": ["AGUA", "ALEMANIA", "AUSTRALIA", "BRASIL", "CHINA", "CORTO", "CORTO", "CORTO", "CORTO", "DIVISAS", "EEUU", "EMERGENTES", "EQUITY MARKET NEUTRAL", "EUROPA", "EUROPA", "GLOBAL", "GLOBAL", "GLOBAL", "GLOBAL", "GROWTH", "HONG KONG", "LARGO", "LARGO", "LARGO", "LARGO", "LARGO", "LARGO", "MADERA", "MULTI ESTRATEGIA", "MULTI ESTRATEGIA", "SMALL CAP", "SUIZA", "TURQUIA", "UK", "VALUE", "VOLATILIDAD", "CONSUMO ESTABLE", "CUIDADO DEL MEDIO AMBIENTE", "ENERGIA", "EUROPA", "EUROPA", "EUROPA", "INVERSION SOCIALMENTE RESPONSABLE", "MONOPAIS", "MONOPAIS", "MONOPAIS", "PANEUROPEO", "PERFIL ALTO", "PERFIL MEDIO", "TECNOLOGIA", "USA", "USA", "USA", "CREDITO", "EMERGENTE", "EUROPA", "GLOBAL", "GOBIERNOS", "HIGH YIELD", "RETORNO ABSOLUTO", "SECTORES", "TEMATICOS", "ALTERNATIVOS", "RENTA FIJA", "RENTA VARIABLE"], "name": "", "parents": ["RENTA VARIABLE/TEMATICOS/CUIDADO DEL MEDIO AMBIENTE", "RENTA VARIABLE/EUROPA/MONOPAIS", "RENTA VARIABLE/GLOBAL/MONOPAIS", "RENTA VARIABLE/EMERGENTE/MONOPAIS", "RENTA VARIABLE/EMERGENTE/MONOPAIS", "RENTA FIJA/CREDITO/EUROPA", "RENTA FIJA/HIGH YIELD/EUROPA", "RENTA FIJA/CREDITO/USA", "RENTA FIJA/HIGH YIELD/USA", "ALTERNAT ...
#                         {"legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidt
