# %% [markdown]
# <img src="images\logo_datai.png" width="400" img style="float: right;">
#
# https://www.unav.edu/web/instituto-de-ciencia-de-los-datos-e-inteligencia-artificial<br>
# Author: Pablo Urruchi Mohino

# %% [markdown]
# ## Extract Tweets into xlsx

# %% [markdown]
# https://www.programcreek.com/python/example/76301/tweepy.Cursor

# %% [raw]
# !pip install tweepy

# %% [raw]
# !pip install tweepy==3.9.0

# %%
import tweepy
import csv
from csv import writer

#!/usr/bin/python
from tweepy import Stream, OAuthHandler
from tweepy.streaming import StreamListener


#cambiar a listener en lugar de setramlistener. due to tweepy version

#from progressbar import ProgressBar, Percentage, Bar #pip install progressbar2
import json
import sys
import time
import datetime
#import math
#from IPython.html.widgets import FloatProgress
#from IPython.display import display

#Twitter app information
# import twitter_keys
# consumer_secret, consumer_key, access_token, access_token_secret = twitter_keys.get_twitter_keys()

# %%
tweepy.__version__
# Out:
# '3.9.0'

# %%
#Twitter app information
consumer_secret = 'YOUR_consumer_secret_HERE'
consumer_key = 'YOUR_consumer_key_HERE'
access_token = 'YOUR_access_token_HERE'
access_token_secret = 'YOUR_access_token_secret_HERE'

# %% [markdown]
# ## Parameters

# %%
data_track = ['biden']

#The number of tweets we want to get
max_tweets = 10
#hours
timeout = 10
data_storage = data_track[0]

print (data_storage)
# Out:
# biden

# %%
st = datetime.datetime.fromtimestamp(time.time()).strftime('%Y-%m-%d %H%M%S')
file_name = data_storage + st + '.csv'
file_name
# Out:
# 'biden2022-11-17 003130.csv'

# %%
timeout = 1 * 60 * timeout
timeout = time.time() + timeout
#file_load = FloatProgress(min=0, max=100)

# %% [markdown]
# ## Connection

# %%
#Get the OAuth token
auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)
api

# %% [markdown]
# ## Started at

# %%
datetime.datetime.utcnow().strftime("%a %b %d %H:%M:%S %Z %Y")
# Out:
# 'Wed Nov 16 23:31:30  2022'

# %% [markdown]
# ## Current file loading progress

# %%
#display(file_load)

# %%
#Create the listener class that receives and saves tweets
class listener(StreamListener):
    #On init, set the counter to zero and create a progress bar
    def __init__(self, api=None):
        self.num_tweets = 0.0
        #self.pbar = ProgressBar(widgets=[Percentage(), Bar()], maxval=max_tweets).start()
        
    #When data is received, do this
    def on_data(self, data):
        #Append the tweet to the 'tweets.txt' file        
        #with open(file_name, 'a') as tweet_file:
        with open(file_name, 'a', newline='', encoding='utf-8') as tweet_file:
            
            csv = writer(tweet_file, lineterminator = '\n')
            #c = csv.writer(open("Myfile.csv", 'w',  newline='', encoding='utf-8'))
            while self.num_tweets < max_tweets:               
                tweet = json.loads(data)
                
                # print(data)
                # disable this line once your testing is done
                print (tweet)
                
                # Pull out as any fields as you can. Examples given in the below
                row = (                   
                    tweet['id_str'],
                    tweet['created_at'],
                    tweet['text'],
                    tweet['lang'],
                    tweet['source'],
                    tweet['user']['screen_name'],
                    tweet['user']['lang'],
                    tweet['user']['description'],
                    tweet['user']['location'],
                    tweet['retweet_count']
                    
                    #Replace XXj with the real names
                    #tweet['XX1'],
                    #tweet['XX2']
                )

                values = row
                
                csv.writerow(values)
                self.num_tweets += 1
                if self.num_tweets == max_tweets:
                    #file_load.value = 0
                    tweet_file.close()
                    return False
                else: 
                    #end loop, maximum reached
                    return True
        #return False
    #Handle any errors that may occur
    def on_error(self, status):
        print (status)

# %%
while time.time() < timeout:
    st = datetime.datetime.fromtimestamp(time.time()).strftime('%Y-%m-%d %H%M%S')
    file_name = data_storage + st + '.csv'
    #Prevent error 420: Connection overlap
    time.sleep(2)
    #Use the listener class for stream processing
    twitterStream = Stream(auth, listener())
    #Filter for these topics
    twitterStream.filter(track=data_track)
    if time.time() >= timeout:
        print ('close')
        #break
# Out:
# {'created_at': 'Wed Nov 16 23:31:28 +0000 2022', 'id': 1593023981073797121, 'id_str': '1593023981073797121', 'text': "RT @ggreenwald: US funding for war in Ukraine in 9 months:\n\nMar: $ 13.6 billion\nMay: $ 40b \nNov: $ 37.7b: Biden's new request\n\nThat $ 91.3…", 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 797403411448819712, 'id_str': '797403411448819712', 'name': 'Rachel', 'screen_name': 'RachelCordeiro7', 'location': 'Honolulu HI', 'url': None, 'description': None, 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 612, 'friends_count': 1012, 'listed_count': 3, 'favourites_count': 172817, 'statuses_count': 20749, 'created_at': 'Sat Nov 12 11:39:23 +0000 2016', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1280425389567864832/A23hKfjd_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1280425389567864832/A23hKfjd_normal.jpg', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Wed Nov 16 15:04:18 +0000 2022', 'id': 1592896349431009280, 'id_str': '1592896349431009280', 'text': "US funding for war in Ukraine in 9 months:\n\nMar: $ 13.6 billion\nMay: $ 40b \nNov: $ 37.7b: Biden's new request\n\nThat… https://t.co/ee17eIbKAb", 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 16076032, 'id_str': '16076032', 'name': 'Glenn Greenwald', 'screen_name': 'ggreenwald', 'location': 'GlennGreenwald@gmail.com', 'url': 'https://linktr.ee/glenngreenwald', 'description': 'Journalist; Author; Co-Founder: The Intercept, @TheInterceptBr; HOPE Shelter (@abrigo_hope), @FreedomofPress, @ongcriadefavela; vegan; Insta: Glenn.11.Greenwald', 'translator_type': 'none', 'protected': False, 'verified': True, 'followers_count': 1884044, 'friends_count': 991, 'listed_count': 21266, 'favourites_count': 19086, 'statuses_count': 85189, 'created_at': 'Mon Sep 01 03:13:32 +0000 2008', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '0084B4', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1092582027994509312/cpYWuYI9_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1092582027994509312/cpYWuYI9_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/16076032/1631885895', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'withhel ...
# {'created_at': 'Wed Nov 16 23:31:29 +0000 2022', 'id': 1593023982525042689, 'id_str': '1593023982525042689', 'text': '@Filippo_Rossi Servi di Putin, servi di Macron , servi di Biden, servi di Scholz....\nSiamo tutti servi, unica opzio… https://t.co/EPXkI2QyKR', 'display_text_range': [15, 140], 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': True, 'in_reply_to_status_id': 1592974630251540480, 'in_reply_to_status_id_str': '1592974630251540480', 'in_reply_to_user_id': 81674060, 'in_reply_to_user_id_str': '81674060', 'in_reply_to_screen_name': 'Filippo_Rossi', 'user': {'id': 1460687863138459648, 'id_str': '1460687863138459648', 'name': 'umberto debiasi', 'screen_name': 'UmbertoDebiasi', 'location': None, 'url': None, 'description': "L'oceano non ha memoria", 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 168, 'friends_count': 247, 'listed_count': 0, 'favourites_count': 14552, 'statuses_count': 9934, 'created_at': 'Tue Nov 16 19:15:53 +0000 2021', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1514546462742528000/XEk9vfPD_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1514546462742528000/XEk9vfPD_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1460687863138459648/1640596164', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'extended_tweet': {'full_text': '@Filippo_Rossi Servi di Putin, servi di Macron , servi di Biden, servi di Scholz....\nSiamo tutti servi, unica opzione scegliersi il padrone. Ma un servo rimane servo', 'display_text_range': [15, 165], 'entities': {'hashtags': [], 'urls': [], 'user_mentions': [{'screen_name': 'Filippo_Rossi', 'name': 'Filippo Rossi', 'id': 81674060, 'id_str': '81674060', 'indices': [0, 14]}], 'symbols': []}}, 'quote_count': 0, 'reply_count': 0, 'retweet_count': 0, 'favorite_count': 0, 'entities': {'hashtags': [], 'urls': [{'url': 'https://t.co/EPXkI2QyKR', 'expanded_url': 'https://twitter.com/i/web/status/1593023982525042689', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}], 'user_mentions': [{'screen_name': 'Filippo_Rossi', 'name': 'Filippo Rossi', 'id': 81674060, 'id_str': '81674060', 'indices': [0, 14]}], 'symbols': []}, 'favorited': False, 'retweeted': False, 'filter_level': 'low', 'lang': 'it', 'timestamp_ms': '1668641489045'}
# {'created_at': 'Wed Nov 16 23:31:29 +0000 2022', 'id': 1593023983347113984, 'id_str': '1593023983347113984', 'text': 'RT @JackPosobiec: . @ElonMusk, there is a declared candidate for President of the United States who has been banned from Twitter, while the…', 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 2921129736, 'id_str': '2921129736', 'name': 'Russ Brown', 'screen_name': 'arbee322', 'location': None, 'url': None, 'description': None, 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 23, 'friends_count': 153, 'listed_count': 0, 'favourites_count': 1581, 'statuses_count': 334, 'created_at': 'Sun Dec 07 02:39:25 +0000 2014', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Wed Nov 16 02:42:28 +0000 2022', 'id': 1592709659672150017, 'id_str': '1592709659672150017', 'text': '. @ElonMusk, there is a declared candidate for President of the United States who has been banned from Twitter, whi… https://t.co/11sgaT3UM2', 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 592730371, 'id_str': '592730371', 'name': 'Jack Posobiec 🇺🇸', 'screen_name': 'JackPosobiec', 'location': 'Washington, DC', 'url': 'https://podcasts.apple.com/us/podcast/human-events-daily-with-jack-posobiec/id1585243541', 'description': 'Senior Editor, http://HumanEvents.com. Veteran Navy intel officer', 'translator_type': 'none', 'protected': False, 'verified': True, 'followers_count': 1856686, 'friends_count': 940, 'listed_count': 8295, 'favourites_count': 119586, 'statuses_count': 149216, 'created_at': 'Mon May 28 13:31:22 +0000 2012', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': True, 'profile_link_color': '1B95E0', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1590214799433924608/OPJo6W2M_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1590214799433924608/OPJo6W2M_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/592730371/1658678326', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': N ...
# {'created_at': 'Wed Nov 16 23:31:29 +0000 2022', 'id': 1593023983557181441, 'id_str': '1593023983557181441', 'text': 'RT @atrupar: a snippet from a Herschel Walker stump speech: "We got people in Washington that have gotten too weak. All they want to do is…', 'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1573505255408824322, 'id_str': '1573505255408824322', 'name': 'pam davison', 'screen_name': 'pamdavison11', 'location': None, 'url': None, 'description': None, 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 24, 'friends_count': 6, 'listed_count': 0, 'favourites_count': 16290, 'statuses_count': 7369, 'created_at': 'Sat Sep 24 02:51:33 +0000 2022', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Wed Nov 16 18:38:43 +0000 2022', 'id': 1592950306757038083, 'id_str': '1592950306757038083', 'text': 'a snippet from a Herschel Walker stump speech: "We got people in Washington that have gotten too weak. All they wan… https://t.co/bpjNl9Lxtq', 'display_text_range': [0, 140], 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 288277167, 'id_str': '288277167', 'name': 'Aaron Rupar', 'screen_name': 'atrupar', 'location': None, 'url': 'http://aaronrupar.substack.com', 'description': 'journalist. sign up for my newsletter, Public Notice (link below). Powered by @SnapStream (more info: https://bit.ly/snapstream-atr22).', 'translator_type': 'none', 'protected': False, 'verified': True, 'followers_count': 790683, 'friends_count': 2032, 'listed_count': 7373, 'favourites_count': 185689, 'statuses_count': 111451, 'created_at': 'Tue Apr 26 15:22:47 +0000 2011', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': True, 'profile_link_color': '1B95E0', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1335565046290804738/eGXNmTvg_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1335565046290804738/eGXNmTvg_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/288277167/1469538346', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'withheld_in_countries': []}, 'geo': None, 'coordin ...
# {'created_at': 'Wed Nov 16 23:31:29 +0000 2022', 'id': 1593023983833710593, 'id_str': '1593023983833710593', 'text': "Rubio denounces Biden meeting with Xi, says president 'dangerously misunderstands' communist leader | Just The News https://t.co/2VcysrdQLa", 'source': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 523248016, 'id_str': '523248016', 'name': 'John Solomon', 'screen_name': 'jsolomonReports', 'location': 'Washington, DC', 'url': 'https://justthenews.com/accountability/media/hold-hold-final-approval-embargoed-until-am-thursday-ne', 'description': 'John Solomon is an award-winning investigative journalist and founder of Just the News. He has worked at AP, WaPo, TWT, and The Hill.', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 865960, 'friends_count': 549, 'listed_count': 2627, 'favourites_count': 126, 'statuses_count': 32826, 'created_at': 'Tue Mar 13 13:19:51 +0000 2012', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1894002095/john_solomon_2583-1-a_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1894002095/john_solomon_2583-1-a_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/523248016/1643390263', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'quote_count': 0, 'reply_count': 0, 'retweet_count': 0, 'favorite_count': 0, 'entities': {'hashtags': [], 'urls': [{'url': 'https://t.co/2VcysrdQLa', 'expanded_url': 'https://trib.al/vknDXAj', 'display_url': 'trib.al/vknDXAj', 'indices': [116, 139]}], 'user_mentions': [], 'symbols': []}, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'filter_level': 'low', 'lang': 'en', 'timestamp_ms': '1668641489357'}
# {'created_at': 'Wed Nov 16 23:31:29 +0000 2022', 'id': 1593023984043712514, 'id_str': '1593023984043712514', 'text': 'RT @MarioDB: Mientras que el régimen asesino cubano arrecia su represión contra familiares de presos politicos, la Administración Biden env…', 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 301057390, 'id_str': '301057390', 'name': 'Iván Hdez Carrillo🇨🇺', 'screen_name': 'ivanlibre', 'location': 'Colón , Matanzas , Cuba🇨🇺.', 'url': 'http://www.cubasindical.org', 'description': 'Secretario Gral de la Asociación Sindical Independiente de #Cuba⚙ ex-prisionero d conciencia dl Grupo d los 75/Teléf:+(53)5 259-9366. No hay tiranía sin lacayos', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 13646, 'friends_count': 13111, 'listed_count': 127, 'favourites_count': 55633, 'statuses_count': 61915, 'created_at': 'Wed May 18 20:11:17 +0000 2011', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'FFCC4D', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme18/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme18/bg.gif', 'profile_background_tile': False, 'profile_link_color': 'FFCC4D', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1579473537307394049/clOuIBkD_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1579473537307394049/clOuIBkD_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/301057390/1632980757', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Wed Nov 16 21:54:55 +0000 2022', 'id': 1592999684465102850, 'id_str': '1592999684465102850', 'text': 'Mientras que el régimen asesino cubano arrecia su represión contra familiares de presos politicos, la Administració… https://t.co/CMMkr5QdeH', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 37094727, 'id_str': '37094727', 'name': 'Mario Diaz-Balart', 'screen_name': 'MarioDB', 'location': 'Florida & Washington, DC', 'url': 'http://mariodiazbalart.house.gov', 'description': "I am proud to represent Florida's 25th Congressional District and serve on @HouseAppropsGOP as Transportation, Housing + Urban Development Ranking Member", 'translator_type': 'none', 'protected': False, 'verified': True, 'followers_count': 72691, 'friends_count': 648, 'listed_count': 1326, 'favourites_count': 1425, 'statuses_count': 10391, 'created_at': 'Sat May 02 00:52:48 +0000 2009', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '042854', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme10/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme10/bg.gif', 'profile_background_tile': False, 'profile_link_color': 'DD2E44', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': '1688AB', 'profile_text_color': '08020D', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/8271 ...
# {'created_at': 'Wed Nov 16 23:31:29 +0000 2022', 'id': 1593023985390063616, 'id_str': '1593023985390063616', 'text': "RT @Jim_Jordan: Target stores are getting looted, and it's taking a huge bite out of profits.\n\nTheft cost the store nearly $400 million thi…", 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 848197437227282433, 'id_str': '848197437227282433', 'name': 'Glenn Elliott', 'screen_name': 'glennEl34443407', 'location': 'Tucson Arizona USA', 'url': None, 'description': '.🇺🇸Social Media,🇺🇸Political News☮️', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 365, 'friends_count': 173, 'listed_count': 0, 'favourites_count': 16662, 'statuses_count': 18584, 'created_at': 'Sat Apr 01 15:36:42 +0000 2017', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1531658158359203841/Vsnv2qiN_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1531658158359203841/Vsnv2qiN_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/848197437227282433/1650842012', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Wed Nov 16 22:51:31 +0000 2022', 'id': 1593013926253719554, 'id_str': '1593013926253719554', 'text': "Target stores are getting looted, and it's taking a huge bite out of profits.\n\nTheft cost the store nearly $400 mil… https://t.co/T8ISl8vVAA", 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 18166778, 'id_str': '18166778', 'name': 'Rep. Jim Jordan', 'screen_name': 'Jim_Jordan', 'location': 'Washington, D.C. ', 'url': 'http://jordan.house.gov/', 'description': "Proudly serving Ohio's beautiful Fourth District. Ranking Member on @JudiciaryGOP. Fighting to #DoWhatWeSaid", 'translator_type': 'none', 'protected': False, 'verified': True, 'followers_count': 3218056, 'friends_count': 3747, 'listed_count': 8385, 'favourites_count': 4527, 'statuses_count': 9648, 'created_at': 'Tue Dec 16 17:20:24 +0000 2008', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'FFFFFF', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': True, 'profile_link_color': '4F90DB', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'BA0D1F', 'profile_text_color': '01050D', 'profile_use_background_image': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/596012379231617025/TtrAXbnA_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/596012379231617025/TtrAXbnA_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/18166778/1406042839', 'default_profile': False, 'default_profile_image': False, 'followin ...
# {'created_at': 'Wed Nov 16 23:31:29 +0000 2022', 'id': 1593023985998262272, 'id_str': '1593023985998262272', 'text': 'RT @prophethusband: Some people can’t stand swagged out white boys', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1117885311705583616, 'id_str': '1117885311705583616', 'name': '✨ Rhett Larsen ✨', 'screen_name': 'RhettLarsen6', 'location': None, 'url': 'https://rhettlarsenportfolio.carrd.co/', 'description': 'Professional Artist :3, One Metamorphin’ Dudicus | PFP by @Myrmidia', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 620, 'friends_count': 1002, 'listed_count': 10, 'favourites_count': 154829, 'statuses_count': 128861, 'created_at': 'Mon Apr 15 20:20:02 +0000 2019', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1532962913484521472/ztZ1qMaZ_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1532962913484521472/ztZ1qMaZ_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1117885311705583616/1666059071', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Tue Nov 15 13:15:06 +0000 2022', 'id': 1592506477960658944, 'id_str': '1592506477960658944', 'text': 'Some people can’t stand swagged out white boys', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 828012211784339456, 'id_str': '828012211784339456', 'name': 'Losing it', 'screen_name': 'prophethusband', 'location': 'Sverige', 'url': None, 'description': 'i do not have opinions', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 40341, 'friends_count': 884, 'listed_count': 85, 'favourites_count': 37532, 'statuses_count': 9976, 'created_at': 'Sat Feb 04 22:47:49 +0000 2017', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1454540910965010435/fxyWMWqA_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1454540910965010435/fxyWMWqA_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/828012211784339456/1652243613', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'quoted_status_id': 1592226577995235330, 'quoted_status_id_str': '1592226577995235330', 'quoted_status': {'created_at': 'Mon Nov 14 18:42: ...
# {'created_at': 'Wed Nov 16 23:31:29 +0000 2022', 'id': 1593023986094739457, 'id_str': '1593023986094739457', 'text': 'RT @Malcolm_fleX48: Sorry Millennial voters, I know you wanted Student Loan forgiveness but.... Best I can do is World War III and 37 Billi…', 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1427687522402975749, 'id_str': '1427687522402975749', 'name': 'arla 🇨🇦 🇺🇸 ⛪️ ONT.#TrudeauMustGo #SaveMyCanada', 'screen_name': 'arla108533291', 'location': 'Ontario', 'url': None, 'description': "Granny to 4...adore Canada\nDon't follow if ur looking for ?Luv\nTwitter's one of those wrong places\n#GroomDogsNotKids\n#NoMrna\n#PPC #CPC", 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 2372, 'friends_count': 4636, 'listed_count': 3, 'favourites_count': 8011, 'statuses_count': 11876, 'created_at': 'Tue Aug 17 17:47:14 +0000 2021', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1436723419240931337/vhDm7xfa_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1436723419240931337/vhDm7xfa_normal.jpg', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Tue Nov 15 20:21:33 +0000 2022', 'id': 1592613800079163395, 'id_str': '1592613800079163395', 'text': 'Sorry Millennial voters, I know you wanted Student Loan forgiveness but.... Best I can do is World War III and 37 B… https://t.co/T4LlfVkQ41', 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 211025537, 'id_str': '211025537', 'name': 'Malcolm FleX', 'screen_name': 'Malcolm_fleX48', 'location': 'Alternate Timeline Earth', 'url': 'http://flexyoursuccess.com', 'description': "#ENTP| 6'5 & Jacked🏋🏿\u200d♀️| Former D1 Athlete 🏃🏿| Clinical Research Scientist 👨🏿\u200d🔬| Anime| Right Libertarian  |Dad👨\u200d👩\u200d👧\u200d👦| Chair of the Hateocracy©️", 'translator_type': 'regular', 'protected': False, 'verified': False, 'followers_count': 61884, 'friends_count': 683, 'listed_count': 155, 'favourites_count': 85855, 'statuses_count': 68860, 'created_at': 'Tue Nov 02 02:41:25 +0000 2010', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '022330', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png', 'profile_background_tile': True, 'profile_link_color': 'FA743E', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'D10B0B', 'profile_text_color': '000000', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1591431176144752641/mllHTY65_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1591431176144752641/mllHTY65_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/21 ...
# {'created_at': 'Wed Nov 16 23:31:29 +0000 2022', 'id': 1593023986098900992, 'id_str': '1593023986098900992', 'text': '@zerba_pagella @pound_sterling @ChristopherJM Even Biden said it was from Ukraine.', 'display_text_range': [46, 82], 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': False, 'in_reply_to_status_id': 1592990638802628608, 'in_reply_to_status_id_str': '1592990638802628608', 'in_reply_to_user_id': 1432777058032181251, 'in_reply_to_user_id_str': '1432777058032181251', 'in_reply_to_screen_name': 'zerba_pagella', 'user': {'id': 1381740191740784652, 'id_str': '1381740191740784652', 'name': 'funkyamishdude', 'screen_name': 'funkyamishdude', 'location': None, 'url': None, 'description': 'Testicle bearing person, pronouns are funky/funky af', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 51, 'friends_count': 131, 'listed_count': 0, 'favourites_count': 15130, 'statuses_count': 3829, 'created_at': 'Mon Apr 12 22:45:34 +0000 2021', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1381740431365574661/ySZvFajn_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1381740431365574661/ySZvFajn_normal.jpg', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'quote_count': 0, 'reply_count': 0, 'retweet_count': 0, 'favorite_count': 0, 'entities': {'hashtags': [], 'urls': [], 'user_mentions': [{'screen_name': 'zerba_pagella', 'name': 'Giovanni Zerba', 'id': 1432777058032181251, 'id_str': '1432777058032181251', 'indices': [0, 14]}, {'screen_name': 'pound_sterling', 'name': 'Pound', 'id': 30178619, 'id_str': '30178619', 'indices': [15, 30]}, {'screen_name': 'ChristopherJM', 'name': 'Christopher Miller', 'id': 16827148, 'id_str': '16827148', 'indices': [31, 45]}], 'symbols': []}, 'favorited': False, 'retweeted': False, 'filter_level': 'low', 'lang': 'en', 'timestamp_ms': '1668641489897'}
# {'created_at': 'Wed Nov 16 23:31:32 +0000 2022', 'id': 1593023996320440320, 'id_str': '1593023996320440320', 'text': 'RT @politvidchannel: BREAKING: Biden and Macron nearly laughed when a reporter asked for reaction to Trump’s 2024 campaign launch', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 266775348, 'id_str': '266775348', 'name': 'James Cunningham ❤️💪🏻🏳️\u200d🌈🇺🇸🇺🇦', 'screen_name': 'JamesC518', 'location': 'New York, USA', 'url': None, 'description': '“Pressure is a privilege” - Billie Jean King', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 2022, 'friends_count': 4667, 'listed_count': 96, 'favourites_count': 171458, 'statuses_count': 207276, 'created_at': 'Tue Mar 15 20:00:38 +0000 2011', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'DD2E44', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': True, 'profile_link_color': 'FA743E', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1549418194456047622/0stjE76Y_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1549418194456047622/0stjE76Y_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/266775348/1658374867', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Wed Nov 16 22:13:07 +0000 2022', 'id': 1593004260987654150, 'id_str': '1593004260987654150', 'text': 'BREAKING: Biden and Macron nearly laughed when a reporter asked for reaction to Trump’s 2024 campaign launch', 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 4878610324, 'id_str': '4878610324', 'name': 'PoliticsVideoChannel', 'screen_name': 'politvidchannel', 'location': 'New York, NY', 'url': 'https://www.politicsvideochannel.com/', 'description': 'FACTS MATTER!  The official Twitter of http://politicsvideochannel.com', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 133790, 'friends_count': 42981, 'listed_count': 629, 'favourites_count': 2795, 'statuses_count': 26856, 'created_at': 'Fri Feb 05 19:25:44 +0000 2016', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1453562764643893257/Kt9zl6ml_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1453562764643893257/Kt9zl6ml_normal.jpg', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors':  ...
# {'created_at': 'Wed Nov 16 23:31:32 +0000 2022', 'id': 1593023996995710976, 'id_str': '1593023996995710976', 'text': 'RT @SaycheeseDGTL: President Biden asks Congress for an additional $37 billion in new emergency aid to Ukraine and $9 billion for COVID-19.…', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1298892260164145152, 'id_str': '1298892260164145152', 'name': 'BossDon_Migo', 'screen_name': 'Rob726_migo', 'location': 'Detroit, MI', 'url': 'http://instagram.com/don_migo726', 'description': 'rich boy mafia', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 413, 'friends_count': 275, 'listed_count': 0, 'favourites_count': 2101, 'statuses_count': 27401, 'created_at': 'Thu Aug 27 07:57:18 +0000 2020', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1484848805849616388/oiEnVSWj_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1484848805849616388/oiEnVSWj_normal.jpg', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Wed Nov 16 17:55:59 +0000 2022', 'id': 1592939554830692352, 'id_str': '1592939554830692352', 'text': 'President Biden asks Congress for an additional $37 billion in new emergency aid to Ukraine and $9 billion for COVI… https://t.co/KR3lOtAvYF', 'display_text_range': [0, 140], 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1149024099995475968, 'id_str': '1149024099995475968', 'name': 'SAY CHEESE! 👄🧀', 'screen_name': 'SaycheeseDGTL', 'location': 'United States', 'url': None, 'description': 'teamsaycheese@gmail.com', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 422738, 'friends_count': 26, 'listed_count': 350, 'favourites_count': 49, 'statuses_count': 43006, 'created_at': 'Wed Jul 10 18:34:28 +0000 2019', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1334349241213456386/30mL3JAm_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1334349241213456386/30mL3JAm_normal.jpg', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'extended_tweet': {'full_text': 'President Biden asks Congress for an additional $37 billion in new emergency aid to Ukraine and $9 billion for COVID ...
# ...
# {'created_at': 'Wed Nov 16 23:31:48 +0000 2022', 'id': 1593024062116466688, 'id_str': '1593024062116466688', 'text': 'RT @PorterLane2023: Dear @GovAbbott @TXsecofstate @TXAG \n\nSend every illegal that crosses your border to THIS JUDGES CITY:\n\n👉🏻Judge Emmet G…', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1570586846651875328, 'id_str': '1570586846651875328', 'name': 'JALY_Cat_00', 'screen_name': 'PorterLane2023', 'location': None, 'url': None, 'description': 'You may be the only Jesus people ever see and the only TRUTH people ever hear. #MakeItCount 🇺🇸💕 #EveryPersonMatters', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 2164, 'friends_count': 1825, 'listed_count': 1, 'favourites_count': 2938, 'statuses_count': 10098, 'created_at': 'Fri Sep 16 01:34:36 +0000 2022', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1590829787530108948/irEVSi7D_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1590829787530108948/irEVSi7D_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1570586846651875328/1663356199', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Wed Nov 16 14:46:45 +0000 2022', 'id': 1592891931381882883, 'id_str': '1592891931381882883', 'text': 'Dear @GovAbbott @TXsecofstate @TXAG \n\nSend every illegal that crosses your border to THIS JUDGES CITY:\n\n👉🏻Judge Emm… https://t.co/k8AtcMdlFC', 'display_text_range': [0, 140], 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1570586846651875328, 'id_str': '1570586846651875328', 'name': 'JALY_Cat_00', 'screen_name': 'PorterLane2023', 'location': None, 'url': None, 'description': 'You may be the only Jesus people ever see and the only TRUTH people ever hear. #MakeItCount 🇺🇸💕 #EveryPersonMatters', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 2164, 'friends_count': 1825, 'listed_count': 1, 'favourites_count': 2938, 'statuses_count': 10097, 'created_at': 'Fri Sep 16 01:34:36 +0000 2022', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1590829787530108948/irEVSi7D_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1590829787530108948/irEVSi7D_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1570586846651875328/1663356199', 'default_profile': True, 'default_profile_image': False, 'foll ...
# {'created_at': 'Wed Nov 16 23:31:48 +0000 2022', 'id': 1593024062392918016, 'id_str': '1593024062392918016', 'text': 'RT @rancanoglenda7: Más represión, más abuso ...coaccionan a todos los familiares..de los presos...pero la administración Biden sigue negoc…', 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1240316823813398534, 'id_str': '1240316823813398534', 'name': 'Salomé #MirenLasPrisionesDeCuba', 'screen_name': 'onceagainsalome', 'location': 'Miami Beach, FL', 'url': 'http://Justicia11J.org', 'description': '📋 @justicia11J 🖋️ @hypermediaed  \nDe La Habana🇨🇺 ella/she\n#SeVaACaer', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 4675, 'friends_count': 2416, 'listed_count': 27, 'favourites_count': 278718, 'statuses_count': 55365, 'created_at': 'Wed Mar 18 16:39:20 +0000 2020', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1560441542724157440/pirDHAbd_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1560441542724157440/pirDHAbd_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1240316823813398534/1643220671', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Wed Nov 16 23:23:02 +0000 2022', 'id': 1593021859045724160, 'id_str': '1593021859045724160', 'text': 'Más represión, más abuso ...coaccionan a todos los familiares..de los presos...pero la administración Biden sigue n… https://t.co/7i4KMQqHm7', 'display_text_range': [0, 140], 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1483285231142588418, 'id_str': '1483285231142588418', 'name': 'Glenda Rancaño', 'screen_name': 'rancanoglenda7', 'location': 'Lehigh Acres, FL', 'url': None, 'description': 'Activista de derechos humanos ,En Cuba existe una dictadura y es mi deber denunciar', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 6311, 'friends_count': 1271, 'listed_count': 10, 'favourites_count': 10313, 'statuses_count': 10588, 'created_at': 'Tue Jan 18 03:49:19 +0000 2022', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1583666839720165382/NWozE08B_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1583666839720165382/NWozE08B_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1483285231142588418/1661470826', 'default_profile': True, 'default_profile_image': False, 'following' ...
# {'created_at': 'Wed Nov 16 23:31:48 +0000 2022', 'id': 1593024062636560384, 'id_str': '1593024062636560384', 'text': 'RT @TheRickWilson: So, did they remove your sense of shame surgically, or was it some kind of genetic alteration?\n\nI mean, you actually typ…', 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 211394889, 'id_str': '211394889', 'name': 'JAS', 'screen_name': 'politij', 'location': 'USA', 'url': None, 'description': None, 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 19, 'friends_count': 287, 'listed_count': 2, 'favourites_count': 7895, 'statuses_count': 4633, 'created_at': 'Wed Nov 03 03:42:20 +0000 2010', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None, 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Wed Nov 16 03:46:58 +0000 2022', 'id': 1592725892148731910, 'id_str': '1592725892148731910', 'text': 'So, did they remove your sense of shame surgically, or was it some kind of genetic alteration?\n\nI mean, you actuall… https://t.co/rmCyK2R72d', 'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 19084896, 'id_str': '19084896', 'name': 'Rick Wilson', 'screen_name': 'TheRickWilson', 'location': 'Florida, Man.', 'url': 'https://pod.link/1650861232', 'description': 'Lincoln Project and Resolute Square guy. Ads. OGNT. IFR pilot. NYT #1 best-selling writer. Host: The Enemies List Podcast. #BeResolute', 'translator_type': 'none', 'protected': False, 'verified': True, 'followers_count': 1555141, 'friends_count': 7244, 'listed_count': 10568, 'favourites_count': 107922, 'statuses_count': 356380, 'created_at': 'Fri Jan 16 20:50:17 +0000 2009', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '1A1B1F', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': True, 'profile_link_color': 'FF691F', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '252429', 'profile_text_color': '666666', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1582459487218040833/q5JJwl3M_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1582459487218040833/q5JJwl3M_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/19084896/1668313199', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None ...
# 420

# %% [markdown]
# ### 1. Make this API request to be specificaly pulling data in Spanish language

# %%
#Hint: Answers can be found in the twitterStream documentation or Stack Overflow

# %% [markdown]
# ### 2. Make this API request to be specificaly targeting a region (Spain).
